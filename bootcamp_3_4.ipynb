# %%
import numpy as np
populasyon=np.random.normal(10,0.2,10000)
orneklem=np.random.choice(populasyon,500)
print('Popülasyon için oran : ', len(populasyon[populasyon > 10.2])/len(populasyon)*100)
print('Örneklem için oran   : ', len(orneklem[orneklem > 10.2])/len(orneklem)*100)
# Out:
# Popülasyon için oran :  16.24
# Örneklem için oran   :  15.2

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.animation as animation
# %matplotlib notebook

# 1000 kere zar atalım
n = 1000

ortalama = []
for i in range(1,n):
    a = np.random.randint(1,7,10)
    ortalama.append(np.average(a))
    
# 10 örneklem seçimi
ortalama[1:10]

def clt(current):
    plt.cla()
    if current == 1000: 
        a.event_source.stop()

    plt.hist(ortalama[0:current])

    plt.gca().set_title('Zar Atışından Beklenen Değer')
    plt.gca().set_xlabel('Zar Atışının Ortalaması')
    plt.gca().set_ylabel('Dağılım')

    plt.annotate('Zar Atışı= {}'.format(current), [3,27])
    
fig = plt.figure()
ani = animation.FuncAnimation(fig, clt, interval=1)
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(8,5))
pop1=np.random.binomial(10,0.2,10000)
pop2=np.random.binomial(10,0.5,10000)

plt.hist(pop1,alpha=0.5, label='Populasyon 1')
plt.hist(pop2,alpha=0.5, label='Populasyon 2')

plt.legend(loc='upper right')
plt.show()

# %%
plt.figure(figsize=(8,5))

orneklem1=np.random.choice(pop1, 100, replace=True)
orneklem2=np.random.choice(pop2, 100, replace=True)

plt.hist(orneklem1, alpha=0.5 , label='Orneklem 1')
plt.hist(orneklem2, alpha=0.5 , label='Orneklem 2')

plt.legend(loc='upper right')
plt.show()

# %%
print("1. Orneklemin ortalamasi : ", orneklem1.mean())
print("2. Orneklemin ortalamasi : ", orneklem2.mean())
print("1. Orneklemin standart sapmasi : ", orneklem1.std())
print("2. Orneklemin standart sapmasi : ", orneklem2.std())
# Out:
# 1. Orneklemin ortalamasi :  2.03
# 2. Orneklemin ortalamasi :  4.87
# 1. Orneklemin standart sapmasi :  1.2202868515230345
# 2. Orneklemin standart sapmasi :  1.5662375298785303

# %%
fark=orneklem2.mean()-orneklem1.mean()
print(fark)
# Out:
# 2.8400000000000003

# %%
boyut=np.array([len(orneklem1), len(orneklem2)])
boyut=np.array([len(orneklem1), len(orneklem2)])
sd= np.array([orneklem1.std(), orneklem2.std()])
sd= np.array([orneklem1.std(), orneklem2.std()])

fark_se=  (sum(sd**2/boyut))**0.5
fark_se = (sum(sd ** 2 / boyut)) ** 0.5 
print(fark/fark_se)
# Out:
# 14.30372043363615

# %%
from scipy.stats import ttest_ind
ttest_degeri = ttest_ind(orneklem1, orneklem2, equal_var=False)
print(ttest_degeri)
# Out:
# Ttest_indResult(statistic=-14.232022135353226, pvalue=1.2969534628429881e-31)

# %%
orneklem=[]
orneklem_ortalamalari=[]
for atis_sayisi in range(1,2000):
    atis=np.random.randint(low=1, high=7 ,size=1)[0]
    orneklem.append(atis)
    orneklem_ortalamalari.append(np.mean(orneklem))

# %%
print(orneklem[0:10])
print(orneklem_ortalamalari[0:10])
# Out:
# [6, 5, 5, 6, 2, 2, 4, 6, 6, 4]
# [6.0, 5.5, 5.333333333333333, 5.5, 4.8, 4.333333333333333, 4.285714285714286, 4.5, 4.666666666666667, 4.6]

# %%
def orneklem_plotla(örneklem_ortalaması,orneklem_sayisi, subplot_no):
    baslik_font = {'family': 'arial', 'color': 'darkred','weight': 'bold','size': 13 }
    eksen_font  = {'family': 'arial', 'color': 'darkblue','weight': 'bold','size': 10 }
    plt.subplot(subplot_no)
    plt.hlines(3.5, 0, orneklem_sayisi, colors= 'r' )
    plt.plot(örneklem_ortalaması[0:orneklem_sayisi])
    plt.ylim((1,6))
    plt.title("Örneklem Sayısı = {}".format(orneklem_sayisi), fontdict = baslik_font)
    plt.xlabel("Örneklem Sayısı", fontdict = eksen_font)
    plt.ylabel("Örneklem Ortalaması", fontdict = eksen_font)
    return plt

# %%
plt.figure(figsize=(15,3), dpi=100)
orneklem_plotla(örneklem_ortalamaları,100, 131) 
orneklem_plotla(örneklem_ortalamaları, 500, 132)
orneklem_plotla(örneklem_ortalamaları, 2000, 133)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-a2cecd6e11ea> in <module>
#       1 plt.figure(figsize=(15,3), dpi=100)
# ----> 2 orneklem_plotla(örneklem_ortalamaları,100, 131)
#       3 orneklem_plotla(örneklem_ortalamaları, 500, 132)
#       4 orneklem_plotla(örneklem_ortalamaları, 2000, 133)
#       5 plt.show()
#
# NameError: name 'örneklem_ortalamaları' is not defined
